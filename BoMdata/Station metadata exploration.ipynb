# %%
getCRANmirrors(all = FALSE, local.only = FALSE)
# Out:
# Warning message in download.file(url, destfile = f, quiet = TRUE):
# "InternetOpenUrl failed: 'A connection with the server could not be established'"Warning message:
# "failed to download mirrors file (cannot open URL 'https://cran.r-project.org/CRAN_mirrors.csv'); using local file 'C:/Users/raf018/AppData/Local/Continuum/Anaconda3/R/doc/CRAN_mirrors.csv'"
#     Name                          Country   City
# 1   0-Cloud [https]               0-Cloud   0-Cloud
# 2   0-Cloud                       0-Cloud   0-Cloud
# 3   Algeria [https]               Algeria   Algiers
# 4   Algeria                       Algeria   Algiers
# 5   Argentina (La Plata)          Argentina La Plata
# 6   Australia (Canberra) [https]  Australia Canberra
# 7   Australia (Canberra)          Australia Canberra
# 8   Australia (Melbourne) [https] Australia Melbourne
# 9   Australia (Perth) [https]     Australia Perth
# 10  Austria [https]               Austria   Wien
# ...

# %%
# Done once, con't do it again!
#install.packages('lattice', repos = "https://mirror.aarnet.edu.au/pub/CRAN/")
# Out:
# Installing package into 'C:/Users/raf018/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'lattice' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\raf018\AppData\Local\Temp\Rtmpw1AmEp\downloaded_packages

# %%
library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.4.4"-- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.0     v purrr   0.2.5
# v tibble  2.0.1     v dplyr   0.7.8
# v tidyr   0.8.1     v stringr 1.3.1
# v readr   1.1.1     v forcats 0.3.0
# Warning message:
# "package 'ggplot2' was built under R version 3.4.4"Warning message:
# "package 'tibble' was built under R version 3.4.4"Warning message:
# "package 'tidyr' was built under R version 3.4.4"Warning message:
# "package 'readr' was built under R version 3.4.4"Warning message:
# "package 'purrr' was built under R version 3.4.4"Warning message:
# "package 'dplyr' was built under R version 3.4.4"Warning message:
# "package 'stringr' was built under R version 3.4.4"Warning message:
# "package 'forcats' was built under R version 3.4.4"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# ...

# %% [markdown]
# # Working with Metadata
#
# Load up metadata files for Water Regulations data set

# %% [markdown]
# ## All of Australia

# %%
setwd("~/Documents/Projects/PhD/Observations/BoMdata")
col_names_metadata_waterregs <- 
  c("Station number", "Agency", "Latitude", "Longitude", "Elevation", "First Date", "First Year", 
    "Last Date", "Last Year", "Number of Years", "Station Name")
metadata_waterregs <- 
  read.csv('Station_Metadata_FinalIFD_Water Regulations_Continuous_reimported.csv', 
           col.names = col_names_metadata_waterregs)

# %%
plot1 <- metadata_waterregs %>% ggplot(aes(x = Longitude, y = Latitude)) + geom_point()
plot1
# Out:
# plot without title

# %%
plot1 + geom_point(aes(col = Number.of.Years))
plot1 + geom_point(aes(col = First.Year))
# Out:
# plot without title
# plot without title

# %%
metadata_waterregs$Agency <- as.factor(metadata_waterregs$Agency)

metadata_waterregs %>% group_by(Agency) %>%
  ggplot(aes(x=Longitude, y=Latitude, col=Agency)) +
  geom_point()

metadata_waterregs %>% filter(Number.of.Years > 25) %>% group_by(Agency) %>%
  ggplot(aes(x=Longitude, y=Latitude, col=Agency)) +
  geom_point()
# Out:
# Warning message:
# "package 'bindrcpp' was built under R version 3.4.4"
# plot without title
# plot without title

# %% [markdown]
# ### Is there a pattern to when various agencies first had their stations installed?

# %%
metadata_waterregs %>% group_by(Agency) %>%
  ggplot(aes(x=First.Year, col=Agency, fill=Agency)) +
  geom_histogram(bins=15, alpha = 0.2)
# Out:
# plot without title

# %% [markdown]
# Not a clear relationship, really...
#
# ### Are there changes to the length of station record over time?

# %%
metadata_waterregs %>% group_by(Agency) %>%
 ggplot(aes(x=First.Year, y=Last.Year, col=Agency)) +
 geom_jitter()
# Out:
# plot without title

# %% [markdown]
# It looks like a significant number of stations ceased operating in the late 1990s, particularly for Agency ~75? (Which agency is this?)
#
# --- FOLLOW UP: IT WAS AGENCY 76, THE WA DEPT OF WATER ---

# %% [markdown]
# ### Add information on physical location of stations:

# %%
# Load in station lookup table from README page of water regs .xls file
metadata_waterregs_stations <- read_csv('Station_Metadata_FinalIFD_Water Regulations_Continuous_README_page.csv', skip = 18, col_names = c("Agency", "OrganisationName", "State"))
# Remove blank rows and values
metadata_waterregs_stations <- metadata_waterregs_stations %>% drop_na()
# Lok at the DF:
metadata_waterregs_stations
# Out:
# Parsed with column specification:
# cols(
#   Agency = col_character(),
#   OrganisationName = col_character(),
#   State = col_character()
# )
#    Agency OrganisationName
# 1  2      ACTEW Corporation Limited
# 2  13     Barwon Region Water Corporation (Barwon Water)
# 3  32     Central Highlands Water
# 4  58     Department of Commerce
# 5  66     Department of Natural Resources and Water
# 6  67     Department of Natural Resources Environment and the Arts
# 7  74     Department of Sustainability and Environment
# 8  75     Department of Territory and Municipal Services
# 9  76     Department of Water
# 10 77     Department of Water and Energy
# 11 78     Department of Water Land and Biodiversity Conservation
# 12 102    Gippsland and Southern Rural Water Corporation (Southern Rural Water)
# 13 129    Hydro-electric Corporation (Hydro Tasmania)
# 14 151    Melbourne Water Corporation (Melbourne Water)
# 15 166    National Capital Authority
# 16 205    Snowy Hydro Limited
# ...

# %%
# Add Org name and State to our DF
metadata <- merge(metadata_waterregs, metadata_waterregs_stations[,c("Agency", "OrganisationName", "State")], by = 'Agency')
metadata
# Out:
#      Agency Station.number Latitude Longitude Elevation First.Date
# 1    102    233200b_102    -38.1434 144.1871     0.0    11:40_08/05/2000
# 2    102    226205d_102    -37.9070 146.0221   238.0    14:05_02/07/1996
# 3    102    225209a_102    -37.6296 146.6233     0.0    17:58_09/10/1992
# 4    102    225231a_102    -37.9750 146.6250     0.0    18:06_18/11/1992
# 5    102    233218b_102    -38.1495 143.9902     0.0    11:54_21/07/1989
# 6    102    233224a_102    -38.3252 143.8334     0.0    10:45_21/05/1993
# 7    102    225709a_102    -38.1331 146.9110     0.0    11:00_16/01/1997
# 8    102    232204b_102    -37.7639 144.1067     0.0    08:40_11/01/2001
# 9    102    224201c_102    -37.4900 147.1664   183.0    14:24_06/10/1992
# 10   129    0003_129       -41.8182 145.8020   941.0    09:57_18/01/1990
# 11   129    0004_129       -41.6616 146.1770   849.3    16:00_23/05/1970
# 12   129    0005_129       -42.2395 146.4938   637.0    12:40_24/08/1999
# ...

# %% [markdown]
# ### Now we can look at which Organisations / Agencies closed their stations when:

# %%
metadata %>% group_by(Last.Year) %>%
 summarise(n())
# Out:
#    Last.Year n()
# 1  1971        2
# 2  1973        1
# 3  1978        2
# 4  1980        2
# 5  1982        1
# 6  1984        2
# 7  1985        2
# 8  1986        8
# 9  1987        6
# 10 1988        9
# 11 1989        5
# 12 1990        1
# 13 1991        2
# 14 1992        6
# 15 1993        3
# 16 1994        2
# 17 1995        5
# 18 1996        2
# 19 1997        5
# 20 1998       23
# 21 1999      137
# 22 2000       34
# 23 2001       24
# 24 2002       21
# 25 2003        9
# 26 2004        8
# 27 2005        5
# 28 2006       19
# 29 2007       51
# 30 2008      618
# 31 2009      430
# 32 2010       81

# %%
# Which organisations closed stations in 1999?
metadata %>% 
  filter(Last.Year == 1999) %>%
  group_by(OrganisationName) %>%
  summarise(n())
# Out:
#   OrganisationName                          n()
# 1 Department of Natural Resources and Water   1
# 2 Department of Water                       135
# 3 Department of Water and Energy              1

# %% [markdown]
# So it appears that the WA Department of Water shut down 135 stations in 1999!

# %% [markdown]
# ### Now we have state attached to our data frame, we can plot stations in certain regions...

# %%
# Now we can show all stations from certain juristictions...
# Show stations in NSW/ACT/Snowy Hydro ("OTHER") colored by org, on a plot with fixed 1:1 aspect ratio:
metadata %>% filter(State == 'NSW' | State == "ACT" | State == 'OTHER') %>%
  ggplot(aes(x=Longitude, y=Latitude, col=OrganisationName)) +
  geom_point(alpha = 0.4) +
  coord_fixed(1) +
  theme(legend.position="right",legend.direction="vertical")
# Out:
# plot without title

# %%
# VIC only, with legend at bottom (to accommodate for VIC being wider than it is tall)
metadata %>% filter(State == 'VIC') %>%
  ggplot(aes(x=Longitude, y=Latitude, col=OrganisationName)) +
  geom_point(alpha = 0.4) +
  coord_fixed(1) +
  theme(legend.position="bottom",legend.direction="vertical")
# Out:
# plot without title

# %% [markdown]
# ### This is okay - but I want to improve mapping, so put it onto a google or osm map background using `ggmaps`

# %%
library(ggmap)
# Out:
# Warning message:
# "package 'ggmap' was built under R version 3.4.2"Google Maps API Terms of Service: http://developers.google.com/maps/terms.
# Please cite ggmap if you use it: see citation("ggmap") for details.

# %%
# Google maps API key: AIzaSyDJeNzaBarybVQ7G4-eZmgD02xAtyOiuBc
api_key <- 'AIzaSyDJeNzaBarybVQ7G4-eZmgD02xAtyOiuBc'
register_google(api_key)

# %%
# Set bounds of NSW region to plot:
nsw <- c(left = 140, right = 154, bottom = -38, top = -28)

# %%
# Draw map with stations:
nsw_map <- ggmap(get_map(nsw, maptype = "toner-lite", zoom = 6))
nsw_map +
geom_point(data = metadata, aes(x = Longitude, y = Latitude, col = Agency), alpha = 0.6)
# Out:
# maptype = "toner-lite" is only available with source = "stamen".
# resetting to source = "stamen"...
# Source : http://tile.stamen.com/toner-lite/6/56/37.png
# Source : http://tile.stamen.com/toner-lite/6/57/37.png
# Source : http://tile.stamen.com/toner-lite/6/58/37.png
# Source : http://tile.stamen.com/toner-lite/6/59/37.png
# Source : http://tile.stamen.com/toner-lite/6/56/38.png
# Source : http://tile.stamen.com/toner-lite/6/57/38.png
# Source : http://tile.stamen.com/toner-lite/6/58/38.png
# Source : http://tile.stamen.com/toner-lite/6/59/38.png
# Source : http://tile.stamen.com/toner-lite/6/56/39.png
# Source : http://tile.stamen.com/toner-lite/6/57/39.png
# Source : http://tile.stamen.com/toner-lite/6/58/39.png
# Source : http://tile.stamen.com/toner-lite/6/59/39.png
# Warning message:
# "Removed 872 rows containing missing values (geom_point)."
# plot without title

# %%
# Want to restrict to data in NSW/ACT/Snowy Hydro, and color (and legend) by names of orgs rather than the Agency number
nsw_data <- metadata %>% filter(State == "NSW" | State == "ACT" | State == "OTHER")
nsw_map +
geom_point(data = nsw_data, aes(x = Longitude, y = Latitude, col = OrganisationName), alpha = 0.6)
# Out:
# plot without title

# %%
# Same plot as above, but switching around to have the plot data in the ggmap `base_layer`
nsw_map <- ggmap(get_map(nsw, maptype = "toner-lite", zoom = 6), 
                 base_layer = ggplot(data = nsw_data, aes(Longitude, Latitude)))

nsw_map +
  geom_point(aes(col = OrganisationName), alpha = 0.6)
# Out:
# maptype = "toner-lite" is only available with source = "stamen".
# resetting to source = "stamen"...
# Source : http://tile.stamen.com/toner-lite/6/56/37.png
# Source : http://tile.stamen.com/toner-lite/6/57/37.png
# Source : http://tile.stamen.com/toner-lite/6/58/37.png
# Source : http://tile.stamen.com/toner-lite/6/59/37.png
# Source : http://tile.stamen.com/toner-lite/6/56/38.png
# Source : http://tile.stamen.com/toner-lite/6/57/38.png
# Source : http://tile.stamen.com/toner-lite/6/58/38.png
# Source : http://tile.stamen.com/toner-lite/6/59/38.png
# Source : http://tile.stamen.com/toner-lite/6/56/39.png
# Source : http://tile.stamen.com/toner-lite/6/57/39.png
# Source : http://tile.stamen.com/toner-lite/6/58/39.png
# Source : http://tile.stamen.com/toner-lite/6/59/39.png
# plot without title

# %%
# Try quick-plotting the maps, facetted by Agency:
qmplot(Longitude, Latitude, color = OrganisationName, data = nsw_data, geom = "point", alpha = I(0.6)) +
  facet_wrap(~ Agency)
# Out:
# Using zoom = 7...
# Source : http://tile.stamen.com/toner-lite/7/115/74.png
# Source : http://tile.stamen.com/toner-lite/7/116/74.png
# Source : http://tile.stamen.com/toner-lite/7/117/74.png
# Source : http://tile.stamen.com/toner-lite/7/118/74.png
# Source : http://tile.stamen.com/toner-lite/7/115/75.png
# Source : http://tile.stamen.com/toner-lite/7/116/75.png
# Source : http://tile.stamen.com/toner-lite/7/117/75.png
# Source : http://tile.stamen.com/toner-lite/7/118/75.png
# Source : http://tile.stamen.com/toner-lite/7/115/76.png
# Source : http://tile.stamen.com/toner-lite/7/116/76.png
# Source : http://tile.stamen.com/toner-lite/7/117/76.png
# Source : http://tile.stamen.com/toner-lite/7/118/76.png
# Source : http://tile.stamen.com/toner-lite/7/115/77.png
# Source : http://tile.stamen.com/toner-lite/7/116/77.png
# Source : http://tile.stamen.com/toner-lite/7/117/77.png
# Source : http://tile.stamen.com/toner-lite/7/118/77.png
# ...

# %% [markdown]
# # Zooming in on our Sydney domain!
#
# Setting the domain to be smaller only works somewhat...
# If we try to plot stations within a bounded region, the plot will only extend as far as the outer stations' location.
# On the other hand, we want to plot the whole region to the boundary, so we set that with limits within `scale_x_continuous`.

# %%
# Where are my domain bounds?
syd_domain <- 
c(left = 148.7, right = 153.2, top = -31.9, bottom = -35.9)

# %%
# Map without domain adjustment:
syd_map <- ggmap(get_map(syd_domain, maptype = "toner-lite", zoom = 8), 
                 base_layer = ggplot(data = nsw_data, aes(Longitude, Latitude)))
syd_map +
geom_point(aes(col = OrganisationName), alpha = 0.6)
# Out:
# maptype = "toner-lite" is only available with source = "stamen".
# resetting to source = "stamen"...
# Source : http://tile.stamen.com/toner-lite/8/233/151.png
# Source : http://tile.stamen.com/toner-lite/8/234/151.png
# Source : http://tile.stamen.com/toner-lite/8/235/151.png
# Source : http://tile.stamen.com/toner-lite/8/236/151.png
# Source : http://tile.stamen.com/toner-lite/8/233/152.png
# Source : http://tile.stamen.com/toner-lite/8/234/152.png
# Source : http://tile.stamen.com/toner-lite/8/235/152.png
# Source : http://tile.stamen.com/toner-lite/8/236/152.png
# Source : http://tile.stamen.com/toner-lite/8/233/153.png
# Source : http://tile.stamen.com/toner-lite/8/234/153.png
# Source : http://tile.stamen.com/toner-lite/8/235/153.png
# Source : http://tile.stamen.com/toner-lite/8/236/153.png
# Source : http://tile.stamen.com/toner-lite/8/233/154.png
# Source : http://tile.stamen.com/toner-lite/8/234/154.png
# Source : http://tile.stamen.com/toner-lite/8/235/154.png
# ...

# %%
# Map WITH adjustment:
syd_map +
    scale_x_continuous(limits = c(syd_domain['left'], syd_domain['right']), expand = c(0, 0)) +
    scale_y_continuous(limits = c(syd_domain['bottom'], syd_domain['top']), expand = c(0, 0)) +
    geom_point(aes(col = OrganisationName), alpha = 0.6)
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# Warning message:
# "Removed 109 rows containing missing values (geom_point)."Warning message in data.frame(x = x.major, y = y.range[1]):
# "row names were found from a short variable and have been discarded"Warning message in data.frame(x = x.range[1], y = y.major):
# "row names were found from a short variable and have been discarded"
# plot without title

# %% [markdown]
# Hmmmm... Not much different!!!! :(
#
# ## Testing different length station records:

# %%
# Histogram of station durations (from first year and last year)
nsw_data %>%
  ggplot(aes(x = Number.of.Years, fill = OrganisationName)) +
  geom_histogram(binwidth = 1) +
  guides(fill = guide_legend(ncol = 2)) +
  #theme_classic() +
  theme(legend.position="bottom",legend.direction="vertical") +
  labs(fill = "Organisation", x = "Length of Station Record (years)")
# Out:
# plot without title

# %% [markdown]
# So most stations have less than 30 years of data. :(

# %%
nsw_data %>% 
  group_by(Number.of.Years) %>% 
    summarise(num = n()) %>%
    arrange(desc(Number.of.Years)) %>%
    mutate(numExceedingNumberOfYears = cumsum(num))
# Out:
#    Number.of.Years num numExceedingNumberOfYears
# 1  78               1    1
# 2  64               1    2
# 3  63               1    3
# 4  55               1    4
# 5  54               2    6
# 6  53               1    7
# 7  50               1    8
# 8  49               1    9
# 9  47               1   10
# 10 44               1   11
# 11 43               1   12
# 12 41               4   16
# 13 40               2   18
# 14 39               3   21
# 15 38               1   22
# 16 37               5   27
# 17 36               1   28
# 18 35               2   30
# 19 34               9   39
# 20 33               3   42
# 21 32               8   50
# 22 31               2   52
# 23 30               4   56
# 24 29               3   59
# 25 28              60  119
# 26 27               9  128
# 27 26              13  141
# 28 25              12  153
# 29 24               5  158
# 30 23              10  168
# 31 22              17  185
# 32 21              35  220
# ...

# %%
nsw_data %>% 
  group_by(Number.of.Years) %>% 
    summarise(num = n()) %>%
    arrange(desc(Number.of.Years)) %>%
    mutate(numExceedingNumberOfYears = cumsum(num), percentExceeding = cumsum(num)*100/sum(num)) %>%
    filter(Number.of.Years == 30 | Number.of.Years == 25 | Number.of.Years == 20) %>%
    select(Number.of.Years, percentExceeding)
# Out:
#   Number.of.Years percentExceeding
# 1 30              13.59223
# 2 25              37.13592
# 3 20              58.49515

# %% [markdown]
# So, from a total of 412 stations, we have just over half of stations with 20+ years; 37% with 25+ years, and <b>only 13.5% with 30+ years</b>.

# %% [markdown]
# # BoM continuous stations

# %%
# Header row:
# Stn Number,Latitude,Longitude,Elevation,First Year,Last Year,Number of Years
metadata_bom_cont <- 
  read.csv('Station_Metadata_FinalIFD_Bureau_continuous.csv', 
           header = TRUE)
head(metadata_bom_cont)
# Out:
#   Stn.Number Latitude Longitude Elevation First.Year Last.Year Number.of.Years
# 1 1012       -14.7925 125.8258  315       1969       2002      34
# 2 1018       -16.4181 126.1025  546       1993       2012      20
# 3 1021       -14.2961 126.6431   23       1970       1998      29
# 4 1025       -15.3797 126.3114  385       1996       2011      16
# 5 2009       -16.4203 126.4411  488       1963       2008      46
# 6 2012       -18.2292 127.6636  422       1955       2011      57

# %% [markdown]
# #### These stations cover all of Australia:

# %%
qmplot(Longitude, Latitude, color = Number.of.Years, data = metadata_bom_cont, geom = "point", alpha = I(0.2))
# Out:
# Using zoom = 4...
# Source : http://tile.stamen.com/toner-lite/4/12/8.png
# Source : http://tile.stamen.com/toner-lite/4/13/8.png
# Source : http://tile.stamen.com/toner-lite/4/14/8.png
# Source : http://tile.stamen.com/toner-lite/4/15/8.png
# Source : http://tile.stamen.com/toner-lite/4/12/9.png
# Source : http://tile.stamen.com/toner-lite/4/13/9.png
# Source : http://tile.stamen.com/toner-lite/4/14/9.png
# Source : http://tile.stamen.com/toner-lite/4/15/9.png
# Source : http://tile.stamen.com/toner-lite/4/12/10.png
# Source : http://tile.stamen.com/toner-lite/4/13/10.png
# Source : http://tile.stamen.com/toner-lite/4/14/10.png
# Source : http://tile.stamen.com/toner-lite/4/15/10.png
# plot without title

# %% [markdown]
# #### Okay. Let's limit our stations to those within the Sydney domain defined earlier:

# %%
syd_bom_cont <- metadata_bom_cont %>% 
  filter(Longitude > syd_domain['left'] & Longitude < syd_domain['right'] & 
           Latitude < syd_domain['top'] & Latitude > syd_domain['bottom'])

# %%
qmplot(Longitude, Latitude, size = Number.of.Years, col = Number.of.Years, data = syd_bom_cont, geom = "point", alpha = I(0.4))
# Out:
# Using zoom = 8...
# plot without title

# %% [markdown]
# Now look at stations with at least N years of record:

# %%
# Points with station record >= 25 years ### USE THIS ###
syd_bom_cont %>%
  filter(Number.of.Years >= 25) %>%
  ggplot(aes(x = Longitude, y = Latitude)) +
  annotation_map(map_data("world"), fill = "NA", col = "grey25") +
  geom_point(alpha = 0.6, col = "red") +
  coord_cartesian(xlim = c(syd_domain['left'], syd_domain['right']),
                  ylim = c(syd_domain['top'], syd_domain['bottom'])) +
  coord_quickmap()
# Out:
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
# plot without title

# %% [markdown]
# Hmmm. That's a bit ugly with the low res coastlines. Stick to using ggmap / qmplot.

# %%
library(maps)
library(mapdata)
library(ggplot2)

# %%
syd_basemap <- fortify(map("worldHires", fill = TRUE, plot = FALSE))
# Out:
# Error in as_mapper(.f, ...): argument ".f" is missing, with no default
# Traceback:
#
# 1. fortify(map("worldHires", fill = TRUE, plot = FALSE))
# 2. map("worldHires", fill = TRUE, plot = FALSE)
# 3. as_mapper(.f, ...)

# %%
# Points with station record >= 25 years ### USE THIS ###
syd_bom_cont %>%
  filter(Number.of.Years >= 25) %>%
  ggplot(aes(x = Longitude, y = Latitude)) +
  annotation_map(map_data("world"), fill = "NA", col = "grey25") +
  geom_point(alpha = 0.6, col = "red") +
  coord_cartesian(xlim = c(syd_domain['left'], syd_domain['right']),
                  ylim = c(syd_domain['top'], syd_domain['bottom'])) +
  coord_quickmap()

# %%
syd_25 <- syd_bom_cont %>% filter(Number.of.Years >= 25) 
head(syd_25)
# Out:
#   Stn.Number Latitude Longitude Elevation First.Year Last.Year Number.of.Years
# 1 60030      -31.9033 152.4496   21       1964       2005      42
# 2 60112      -32.0525 151.9147  125       1982       2011      30
# 3 61078      -32.7932 151.8359    9       1952       2011      60
# 4 61089      -32.0632 150.9272  216       1952       2011      60
# 5 61151      -32.2426 151.6830  194       1960       2011      52
# 6 61158      -32.5067 151.3779   60       1964       2011      48

# %%
# Map these 25+ year locations:
ggmap(get_map(syd_domain, maptype = "toner-lite", zoom = 8), 
                 base_layer = ggplot(data = syd_25, aes(Longitude, Latitude))) +
geom_point(aes(col = Elevation), alpha = 0.6)
# Out:
# maptype = "toner-lite" is only available with source = "stamen".
# resetting to source = "stamen"...
# Source : http://tile.stamen.com/toner-lite/8/233/151.png
# Source : http://tile.stamen.com/toner-lite/8/234/151.png
# Source : http://tile.stamen.com/toner-lite/8/235/151.png
# Source : http://tile.stamen.com/toner-lite/8/236/151.png
# Source : http://tile.stamen.com/toner-lite/8/233/152.png
# Source : http://tile.stamen.com/toner-lite/8/234/152.png
# Source : http://tile.stamen.com/toner-lite/8/235/152.png
# Source : http://tile.stamen.com/toner-lite/8/236/152.png
# Source : http://tile.stamen.com/toner-lite/8/233/153.png
# Source : http://tile.stamen.com/toner-lite/8/234/153.png
# Source : http://tile.stamen.com/toner-lite/8/235/153.png
# Source : http://tile.stamen.com/toner-lite/8/236/153.png
# Source : http://tile.stamen.com/toner-lite/8/233/154.png
# Source : http://tile.stamen.com/toner-lite/8/234/154.png
# Source : http://tile.stamen.com/toner-lite/8/235/154.png
# ...

# %%
qmplot(Longitude, Latitude, size = Number.of.Years, col = Elevation, data = syd_25, geom = "point", alpha = I(0.4))
# Out:
# Using zoom = 8...
# plot without title

# %% [markdown]
# This is pretty similar, but the margins are slightly larger - perhaps to accommodate for the increased size of data points?
#
#
# ### Now, testing out a few different backgrounds:

# %%
#qmplot(Longitude, Latitude, size = Number.of.Years, col = Elevation, data = syd_25, geom = "point", alpha = I(0.4), source = "stamen", maptype = "terrain", mapcolor = "bw") 
#syd_25 %>%
    ggmap(get_map(syd_domain, source = "stamen", maptype = "terrain-background", color = "bw", zoom = 8), 
                 base_layer = ggplot(data = syd_25, aes(Longitude, Latitude))) +
geom_point(aes(col = Elevation), alpha = 0.8)
# Out:
# Source : http://tile.stamen.com/terrain-background/8/233/151.png
# Source : http://tile.stamen.com/terrain-background/8/234/151.png
# Source : http://tile.stamen.com/terrain-background/8/235/151.png
# Source : http://tile.stamen.com/terrain-background/8/236/151.png
# Source : http://tile.stamen.com/terrain-background/8/233/152.png
# Source : http://tile.stamen.com/terrain-background/8/234/152.png
# Source : http://tile.stamen.com/terrain-background/8/235/152.png
# Source : http://tile.stamen.com/terrain-background/8/236/152.png
# Source : http://tile.stamen.com/terrain-background/8/233/153.png
# Source : http://tile.stamen.com/terrain-background/8/234/153.png
# Source : http://tile.stamen.com/terrain-background/8/235/153.png
# Source : http://tile.stamen.com/terrain-background/8/236/153.png
# Source : http://tile.stamen.com/terrain-background/8/233/154.png
# Source : http://tile.stamen.com/terrain-background/8/234/154.png
# ...

# %%
ggmap(get_map(syd_domain, source = "stamen", maptype = "toner-background", color = "bw", zoom = 8), 
                 base_layer = ggplot(data = syd_25, aes(Longitude, Latitude))) +
geom_point(aes(col = Elevation), alpha = 0.8)
# Out:
# Source : http://tile.stamen.com/toner-background/8/233/151.png
# Source : http://tile.stamen.com/toner-background/8/234/151.png
# Source : http://tile.stamen.com/toner-background/8/235/151.png
# Source : http://tile.stamen.com/toner-background/8/236/151.png
# Source : http://tile.stamen.com/toner-background/8/233/152.png
# Source : http://tile.stamen.com/toner-background/8/234/152.png
# Source : http://tile.stamen.com/toner-background/8/235/152.png
# Source : http://tile.stamen.com/toner-background/8/236/152.png
# Source : http://tile.stamen.com/toner-background/8/233/153.png
# Source : http://tile.stamen.com/toner-background/8/234/153.png
# Source : http://tile.stamen.com/toner-background/8/235/153.png
# Source : http://tile.stamen.com/toner-background/8/236/153.png
# Source : http://tile.stamen.com/toner-background/8/233/154.png
# Source : http://tile.stamen.com/toner-background/8/234/154.png
# Source : http://tile.stamen.com/toner-background/8/235/154.png
# ...

# %%
# Try out another map base package:
devtools::install_github("dr-harper/ggmapstyles")
# Out:
# Skipping install of 'ggmapstyles' from a github remote, the SHA1 (093261ec) has not changed since last install.
#   Use `force = TRUE` to force installation

# %% [markdown]
# Okay then, that didn't work... Try another package for Hi-res maps!
#
# ## Loading `worldHires` from `mapdata` package:

# %%
library(maps)
library(mapdata)
map <- fortify(map("worldHires", fill = TRUE, plot = FALSE))
# Out:
# Error in as_mapper(.f, ...): argument ".f" is missing, with no default
# Traceback:
#
# 1. fortify(map("worldHires", fill = TRUE, plot = FALSE))
# 2. map("worldHires", fill = TRUE, plot = FALSE)
# 3. as_mapper(.f, ...)
